# %%
import pyodbc
connection = pyodbc.connect('DRIVER={ODBC Driver 13 for SQL Server};SERVER=mssql;DATABASE=ecology;UID=root;PWD=Do8gjas07gaS1')
curs = connection.execute('select * from test')
curs.fetchone()
# Out:
# (1, )

# %%
import pyodbc
db = pyodbc.connect('DRIVER={SQL Server}; SERVER=127.0.0.1; DATABASE=ecology; UID=sa; PWD=Do8gjas07gaS1')
curs = db.execute('select * from test')
print(curs.fetchone())
# db.close()
# Out:
# (1, )

# %%
import pandas as pd

# %%
import pandas as pd
from sqlalchemy import create_engine

USER = "root"
PASSWORD = "Do8gjas07gaS1"
HOST = "localhost"
DATABASE = "ecology"

def sql_engine():
    engine_str = "mssql+pyodbc://" + USER + ":" + PASSWORD + "@" + HOST + "/" + DATABASE + "?driver=SQL+Server"
    engine = create_engine(engine_str)
    return engine

engine = sql_engine()

df = pd.read_sql('select top 10 * from test', engine)

# %%
df = pd.read_sql("select distinct years, months from cp_result", engine)

# %%
df.years.astype(str) + df.months.astype(str).str.pad(2, 'left', '0')
# Out:
# 0    202003
# 1    202004
# dtype: object

# %%
# Out:
# 0    03
# 1    04
# Name: months, dtype: object

# %%
from django.shortcuts import reverse

# %%
url = 'http://localhost:8000/dtl/?name=huangyouhua&month=202004&group=7'

# %%
import urllib.parse as parse

# %%
dict(parse.parse_qsl(parse.urlsplit(url).query))
# Out:
# {'name': 'huangyouhua', 'month': '202004', 'group': '7'}

# %%
from dataclasses import dataclass
from sqlalchemy import create_engine
@dataclass
class MSSQL_SETTINGS():
    NAME = 'ecology'
    HOST = 'MSSQL'
    PORT = 1433
    USER = 'sa'
    PASSWORD = 'Do8gjas07gaS1'
    DRIVER = 'ODBC Driver 13 for SQL Server'

# %%
USER = MSSQL_SETTINGS.USER
PASSWORD = MSSQL_SETTINGS.PASSWORD
HOST = MSSQL_SETTINGS.HOST
DATABASE = MSSQL_SETTINGS.NAME
DRIVER = MSSQL_SETTINGS.DRIVER.replace(' ', '+')

# %%
engine_str = "mssql+pyodbc://" + USER + ":" + PASSWORD + "@" + HOST + "/" + DATABASE + "?driver=" + DRIVER
engine_str
# Out:
# 'mssql+pyodbc://sa:Do8gjas07gaS1@MSSQL/ecology?driver=ODBC+Driver+13+for+SQL+Server'

# %%
engine = create_engine('mssql+pyodbc://sa:Do8gjas07gaS1@localhost/ecology?driver=SQL+Server')

# %%
def sql_engine():
    engine_str = "mssql+pyodbc://" + USER + ":" + PASSWORD + "@" + HOST + "/" + DATABASE + "?driver=" + DRIVER
    engine = create_engine(engine_str)
    return engine

engine = sql_engine()

# %%
import pandas as pd

# %%
pd.read_sql('select top 2 * from test', engine)
# Out:
#    t1
# 0   1
# 1   2

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:00000@localhost:3306/appraisal')

df = pd.read_sql('''
SELECT id,departmentname,supdepid FROM ecology.hrmdepartment
where canceled is null
''', engine)

department_framework = {}
for i,(id, dep, sup) in df.iterrows():
    department_framework.setdefault(sup, [])
    department_framework[sup].append((id,dep))
department_framework

DEP_FRAM = {}
class Tree:
    def __init__(self, id, departmentname):
        self.id = id
        self.departmentname = departmentname
        self.parent = []
        self.offspring = {}

    def add_parent(self, supdepid):
        self.parent.append(supdepid)

    def add_offspring(self, id, departmentname):
        DEP_FRAM.setdefault(id, Tree(id, departmentname))
        self.offspring[id] = DEP_FRAM[id] 
    
    def get_offsprings(self, id, pre_fix=''):
        print(pre_fix + self.offspring[id].departmentname)
        pre_fix += '  '
        if self.offspring[id].offspring:
            for key in self.offspring[id].offsprint:
                self.offspring[id].offsprint[key].get_offsprints(key, )


for i,(id, dep, sup) in df.iterrows():
    DEP_FRAM[id] = Tree(id, dep)

for i,(id, dep, sup) in df.iterrows():
    if sup not in DEP_FRAM: continue
    DEP_FRAM[sup].add_offspring(id, dep)

DEP_FRAM[1].offspring

# %%
df = pd.read_sql('''
select loginid,departmentid from ecology.permission
''', engine)

# %%
df.groupby('loginid').agg(list).to_dict()['departmentid']
# Out:
# {'departmentid': {'denglifeng': [1, 80], 'huangyouhua': [80]}}

# %% [markdown]
# # Download data

# %%
import os
import urllib
base_dir = 'data/'

# %%
base_urls = {
   'zycwzb'： 'http://quotes.money.163.com/service/zycwzb_{}.html?type=report', # '主要财务指标':
   'cwbbzy'： 'http://quotes.money.163.com/service/cwbbzy_{}.html', # '财务报表摘要':
   'xjllb'： 'http://quotes.money.163.com/service/xjllb_{}.html', # '现金流量表':
   'lrb' ： 'http://quotes.money.163.com/service/lrb_{}.html', # '利润表':
   'zcfzb'： 'http://quotes.money.163.com/service/zcfzb_{}.html', # '资产负债表':
}

# %%
codes = [600779]

# %%
def download_csvs(code):
    print(f'Start downloading files for {code}')
    for key, url in base_urls.items():
        file_path = base_dir + f'{code}_{key}.csv'
        url = url.format(code)
        urllib.request.urlretrieve(url, file_path)
        print(f'Successfully download {key}')
    print(f'Done for {code}')

# %%
download_csvs(codes[0])
# Out:
# Start downloading files for 600779
# Successfully download zycwzb
# Successfully download xjllb
# Successfully download lrb
# Successfully download zcfzb
# Successfully download cwbbzy
# Done for 600779

# %%
import pandas as pd

# %%
code = 600779

# %%
from dataclasses import dataclass

# %%
@dataclass
class CompanyFD():
    zycwzb: pd.DataFrame
    cwbbzy: pd.DataFrame
    xjllb: pd.DataFrame
    lrb: pd.DataFrame
    zcfzb: pd.DataFrame

# %%
def get_company_fd(code):
    df_zycwzb = pd.read_csv(base_dir + f'{code}_zycwzb.csv', encoding='gb2312',index_col=[0], na_values='--', )
    df_cwbbzy = pd.read_csv(base_dir + f'{code}_cwbbzy.csv', encoding='gb2312',index_col=[0], na_values='--')
    df_xjllb = pd.read_csv(base_dir + f'{code}_xjllb.csv', encoding='gb2312',index_col=[0], na_values='--')
    df_lrb = pd.read_csv(base_dir + f'{code}_lrb.csv', encoding='gb2312',index_col=[0], na_values='--')
    df_zcfzb = pd.read_csv(base_dir + f'{code}_zcfzb.csv', encoding='gb2312',index_col=[0], na_values='--')
    return CompanyFD(df_zycwzb, df_cwbbzy, df_xjllb, df_lrb, df_zcfzb)

# %%
sjf = get_company_fd(code)

# %%
pd.read_csv(base_dir + f'{code}_xjllb.csv', encoding='gb2312',index_col=[0], na_values='--').fillna(0)
# Out:
#                                  2019-09-30  2019-06-30  2019-03-31  \
#  报告日期
#  销售商品、提供劳务收到的现金(万元)                300206.0    190813.0    100917.0
#  客户存款和同业存放款项净增加额(万元)                    0.0         0.0         0.0
#  向中央银行借款净增加额(万元                         0.0         0.0         0.0
#  向其他金融机构拆入资金净增加额(万元)                    0.0         0.0         0.0
#  收到原保险合同保费取得的现金(万元)                     0.0         0.0         0.0
#  收到再保险业务现金净额(万元)                        0.0         0.0         0.0
#  保户储金及投资款净增加额(万元)                       0.0         0.0         0.0
#  处置交易性金融资产净增加额(万元)                      0.0         0.0         0.0
#  收取利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  拆入资金净增加额(万元)                           0.0         0.0         0.0
#  回购业务资金净增加额(万元)                         0.0         0.0         0.0
#  收到的税费返还(万元)                            0.0         0.0         0.0
#  收到的其他与经营活动有关的现金(万元)                 4495.0      1264.0       506.0
#  经营活动现金流入小计(万元)                    304701.0    192077.0    101423.0
#  购买商品、接受劳务支付的现金(万元)                 54782.0     29987.0     17684.0
#  客户贷款及垫款净增加额(万元)                        0.0         0.0         0.0
#  存放中央银行和同业款项净增加额(万元)                    0.0         0.0         0.0
#  支付原保险合同赔付款项的现金(万元)                     0.0         0.0         0.0
#  支付利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  支付保单红利的现金(万元)                          0.0         0.0         0.0
#  支付给职工以及为职工支付的现金(万元)                26153.0     14630.0      7656.0
#  支付的各项税费(万元)                        84483.0     61474.0     35576.0
#  支付的其他与经营活动有关的现金(万元)                67359.0     35551.0     15871.0
#  经营活动现金流出小计(万元)                    232776.0    141642.0     76787.0
#  经营活动产生的现金流量净额(万元)                  71925.0     50435.0     24636.0
#  收回投资所收到的现金(万元)                        44.0         0.0         0.0
#  取得投资收益所收到的现金(万元)                       0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)         0.0         0.0         0.0
#  处置子公司及其他营业单位收到的现金净额(万元)                0.0         0.0         0.0
#  收到的其他与投资活动有关的现金(万元)                    0.0         0.0         0.0
# ...                                     ...         ...         ...
#  资产减值准备(万元)                             0.0       333.0         0.0
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)              0.0      2504.0         0.0
#  无形资产摊销(万元)                             0.0       232.0         0.0
#  长期待摊费用摊销(万元)                           0.0        60.0         0.0
#  待摊费用的减少(万元)                            0.0         0.0         0.0
#  预提费用的增加(万元)                            0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产的损失(万元)              0.0       102.0         0.0
#  固定资产报废损失(万元)                           0.0         0.0         0.0
#  公允价值变动损失(万元)                           0.0         0.0         0.0
#  递延收益增加(减：减少)(万元)                       0.0         0.0         0.0
#  预计负债(万元)                               0.0         0.0         0.0
#  财务费用(万元)                               0.0         0.0         0.0
#  投资损失(万元)                               0.0         0.0         0.0
#  递延所得税资产减少(万元)                          0.0     -4208.0         0.0
#  递延所得税负债增加(万元)                          0.0       -11.0         0.0
#  存货的减少(万元)                              0.0     -7886.0         0.0
#  经营性应收项目的减少(万元)                         0.0     -1275.0         0.0
#  经营性应付项目的增加(万元)                         0.0     26762.0         0.0
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0         0.0         0.0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0         0.0         0.0
#  其他(万元)                                 0.0      -136.0         0.0
#  经营活动产生现金流量净额(万元)                       0.0     50435.0         0.0
#  债务转为资本(万元)                             0.0         0.0         0.0
#  一年内到期的可转换公司债券(万元)                      0.0         0.0         0.0
#  融资租入固定资产(万元)                           0.0         0.0         0.0
#  现金的期末余额(万元)                       117341.0    150402.0    126179.0
#  现金的期初余额(万元)                       102519.0    102519.0    102587.0
#  现金等价物的期末余额(万元)                         0.0         0.0         0.0
#  现金等价物的期初余额(万元)                         0.0         0.0         0.0
#  现金及现金等价物的净增加额(万元)                  14822.0     47883.0     23593.0
#
#                                  2018-12-31  2018-09-30  2018-06-30  \
#  报告日期
#  销售商品、提供劳务收到的现金(万元)                316558.0    228071.0    146610.0
#  客户存款和同业存放款项净增加额(万元)                    0.0         0.0         0.0
#  向中央银行借款净增加额(万元                         0.0         0.0         0.0
#  向其他金融机构拆入资金净增加额(万元)                    0.0         0.0         0.0
#  收到原保险合同保费取得的现金(万元)                     0.0         0.0         0.0
#  收到再保险业务现金净额(万元)                        0.0         0.0         0.0
#  保户储金及投资款净增加额(万元)                       0.0         0.0         0.0
#  处置交易性金融资产净增加额(万元)                      0.0         0.0         0.0
#  收取利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  拆入资金净增加额(万元)                           0.0         0.0         0.0
#  回购业务资金净增加额(万元)                         0.0         0.0         0.0
#  收到的税费返还(万元)                            0.0      3894.0         0.0
#  收到的其他与经营活动有关的现金(万元)                 3289.0      2131.0      1686.0
#  经营活动现金流入小计(万元)                    319847.0    234097.0    148296.0
#  购买商品、接受劳务支付的现金(万元)                 90731.0     76113.0     52472.0
#  客户贷款及垫款净增加额(万元)                        0.0         0.0         0.0
#  存放中央银行和同业款项净增加额(万元)                    0.0         0.0         0.0
#  支付原保险合同赔付款项的现金(万元)                     0.0         0.0         0.0
#  支付利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  支付保单红利的现金(万元)                          0.0         0.0         0.0
#  支付给职工以及为职工支付的现金(万元)                34644.0     26490.0     15631.0
#  支付的各项税费(万元)                        78394.0     60237.0     42105.0
#  支付的其他与经营活动有关的现金(万元)                72969.0     56601.0     39280.0
#  经营活动现金流出小计(万元)                    276738.0    219441.0    149488.0
#  经营活动产生的现金流量净额(万元)                  43109.0     14657.0     -1192.0
#  收回投资所收到的现金(万元)                         0.0         0.0         0.0
#  取得投资收益所收到的现金(万元)                       0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)         5.0         5.0         0.0
#  处置子公司及其他营业单位收到的现金净额(万元)                0.0         0.0         0.0
#  收到的其他与投资活动有关的现金(万元)                    0.0       130.0       130.0
# ...                                     ...         ...         ...
#  资产减值准备(万元)                            24.0         0.0      -321.0
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)           4053.0         0.0      1863.0
#  无形资产摊销(万元)                           498.0         0.0       249.0
#  长期待摊费用摊销(万元)                         196.0         0.0        99.0
#  待摊费用的减少(万元)                            0.0         0.0         0.0
#  预提费用的增加(万元)                            0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产的损失(万元)            702.0         0.0        47.0
#  固定资产报废损失(万元)                           0.0         0.0         0.0
#  公允价值变动损失(万元)                           0.0         0.0         0.0
#  递延收益增加(减：减少)(万元)                       0.0         0.0         0.0
#  预计负债(万元)                           -3000.0         0.0         0.0
#  财务费用(万元)                              17.0         0.0         0.0
#  投资损失(万元)                               0.0         0.0         0.0
#  递延所得税资产减少(万元)                        -30.0         0.0     -2527.0
#  递延所得税负债增加(万元)                        831.0         0.0         0.0
#  存货的减少(万元)                         -42756.0         0.0    -33115.0
#  经营性应收项目的减少(万元)                      7670.0         0.0      3899.0
#  经营性应付项目的增加(万元)                     16891.0         0.0      1868.0
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0         0.0         0.0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0         0.0         0.0
#  其他(万元)                                -4.0         0.0         0.0
#  经营活动产生现金流量净额(万元)                   43109.0         0.0     -1192.0
#  债务转为资本(万元)                             0.0         0.0         0.0
#  一年内到期的可转换公司债券(万元)                      0.0         0.0         0.0
#  融资租入固定资产(万元)                           0.0         0.0         0.0
#  现金的期末余额(万元)                       102519.0     79357.0     94751.0
#  现金的期初余额(万元)                       102893.0    102893.0    102893.0
#  现金等价物的期末余额(万元)                         0.0         0.0         0.0
#  现金等价物的期初余额(万元)                         0.0         0.0         0.0
#  现金及现金等价物的净增加额(万元)                   -374.0    -23536.0     -8142.0
#
#                                  2018-03-31  2017-12-31  2017-09-30  \
#  报告日期
#  销售商品、提供劳务收到的现金(万元)                 76739.0    248941.0    169397.0
#  客户存款和同业存放款项净增加额(万元)                    0.0         0.0         0.0
#  向中央银行借款净增加额(万元                         0.0         0.0         0.0
#  向其他金融机构拆入资金净增加额(万元)                    0.0         0.0         0.0
#  收到原保险合同保费取得的现金(万元)                     0.0         0.0         0.0
#  收到再保险业务现金净额(万元)                        0.0         0.0         0.0
#  保户储金及投资款净增加额(万元)                       0.0         0.0         0.0
#  处置交易性金融资产净增加额(万元)                      0.0         0.0         0.0
#  收取利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  拆入资金净增加额(万元)                           0.0         0.0         0.0
#  回购业务资金净增加额(万元)                         0.0         0.0         0.0
#  收到的税费返还(万元)                            0.0         0.0         0.0
#  收到的其他与经营活动有关的现金(万元)                 1249.0      2287.0       966.0
#  经营活动现金流入小计(万元)                     77987.0    251228.0    170363.0
#  购买商品、接受劳务支付的现金(万元)                 34535.0     58662.0     39238.0
#  客户贷款及垫款净增加额(万元)                        0.0         0.0         0.0
#  存放中央银行和同业款项净增加额(万元)                    0.0         0.0         0.0
#  支付原保险合同赔付款项的现金(万元)                     0.0         0.0         0.0
#  支付利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  支付保单红利的现金(万元)                          0.0         0.0         0.0
#  支付给职工以及为职工支付的现金(万元)                 9774.0     25101.0     20674.0
#  支付的各项税费(万元)                        23183.0     61042.0     43050.0
#  支付的其他与经营活动有关的现金(万元)                19810.0     45280.0     30454.0
#  经营活动现金流出小计(万元)                     87301.0    190085.0    133416.0
#  经营活动产生的现金流量净额(万元)                  -9314.0     61143.0     36947.0
#  收回投资所收到的现金(万元)                         0.0         0.0         0.0
#  取得投资收益所收到的现金(万元)                       0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)         0.0        45.0       121.0
#  处置子公司及其他营业单位收到的现金净额(万元)                0.0         0.0         0.0
#  收到的其他与投资活动有关的现金(万元)                   80.0     22435.0     22435.0
# ...                                     ...         ...         ...
#  资产减值准备(万元)                             0.0     10650.0         0.0
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)              0.0      3533.0         0.0
#  无形资产摊销(万元)                             0.0       386.0         0.0
#  长期待摊费用摊销(万元)                           0.0       128.0         0.0
#  待摊费用的减少(万元)                            0.0         0.0         0.0
#  预提费用的增加(万元)                            0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产的损失(万元)              0.0       800.0         0.0
#  固定资产报废损失(万元)                           0.0         0.0         0.0
#  公允价值变动损失(万元)                           0.0         0.0         0.0
#  递延收益增加(减：减少)(万元)                       0.0         0.0         0.0
#  预计负债(万元)                               0.0      2925.0         0.0
#  财务费用(万元)                               0.0      -245.0         0.0
#  投资损失(万元)                               0.0         0.0         0.0
#  递延所得税资产减少(万元)                          0.0     -4232.0         0.0
#  递延所得税负债增加(万元)                          0.0         0.0         0.0
#  存货的减少(万元)                              0.0    -22104.0         0.0
#  经营性应收项目的减少(万元)                         0.0     -9162.0         0.0
#  经营性应付项目的增加(万元)                         0.0     44933.0         0.0
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0         0.0         0.0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0         0.0         0.0
#  其他(万元)                                 0.0         0.0         0.0
#  经营活动产生现金流量净额(万元)                       0.0     61143.0         0.0
#  债务转为资本(万元)                             0.0         0.0         0.0
#  一年内到期的可转换公司债券(万元)                      0.0         0.0         0.0
#  融资租入固定资产(万元)                           0.0         0.0         0.0
#  现金的期末余额(万元)                        91188.0    102893.0     83601.0
#  现金的期初余额(万元)                       102893.0     50429.0     50429.0
#  现金等价物的期末余额(万元)                         0.0         0.0         0.0
#  现金等价物的期初余额(万元)                         0.0         0.0         0.0
#  现金及现金等价物的净增加额(万元)                 -11705.0     52464.0     33172.0
#
#                                  2017-06-30  ...  2008-03-31  2007-12-31  \
#  报告日期                                        ...
#  销售商品、提供劳务收到的现金(万元)                 96200.0  ...     46140.0      150227
#  客户存款和同业存放款项净增加额(万元)                    0.0  ...         0.0           0
#  向中央银行借款净增加额(万元                         0.0  ...         0.0           0
#  向其他金融机构拆入资金净增加额(万元)                    0.0  ...         0.0           0
#  收到原保险合同保费取得的现金(万元)                     0.0  ...         0.0           0
#  收到再保险业务现金净额(万元)                        0.0  ...         0.0           0
#  保户储金及投资款净增加额(万元)                       0.0  ...         0.0           0
#  处置交易性金融资产净增加额(万元)                      0.0  ...         0.0           0
#  收取利息、手续费及佣金的现金(万元)                     0.0  ...         0.0           0
#  拆入资金净增加额(万元)                           0.0  ...         0.0           0
#  回购业务资金净增加额(万元)                         0.0  ...         0.0           0
#  收到的税费返还(万元)                            0.0  ...         0.0         126
#  收到的其他与经营活动有关的现金(万元)                  538.0  ...      2952.0        1045
#  经营活动现金流入小计(万元)                     96738.0  ...     49091.0      151398
#  购买商品、接受劳务支付的现金(万元)                 26904.0  ...     11080.0       32533
#  客户贷款及垫款净增加额(万元)                        0.0  ...         0.0           0
#  存放中央银行和同业款项净增加额(万元)                    0.0  ...         0.0           0
#  支付原保险合同赔付款项的现金(万元)                     0.0  ...         0.0           0
#  支付利息、手续费及佣金的现金(万元)                     0.0  ...         0.0           0
#  支付保单红利的现金(万元)                          0.0  ...         0.0           0
#  支付给职工以及为职工支付的现金(万元)                13926.0  ...      2865.0        5734
#  支付的各项税费(万元)                        28006.0  ...     24789.0       43155
#  支付的其他与经营活动有关的现金(万元)                17193.0  ...      4291.0       10485
#  经营活动现金流出小计(万元)                     86030.0  ...     43026.0       91906
#  经营活动产生的现金流量净额(万元)                  10708.0  ...      6065.0       59492
#  收回投资所收到的现金(万元)                         0.0  ...         0.0        5693
#  取得投资收益所收到的现金(万元)                       0.0  ...         0.0           0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)        45.0  ...         2.0          19
#  处置子公司及其他营业单位收到的现金净额(万元)                0.0  ...         0.0         899
#  收到的其他与投资活动有关的现金(万元)                    0.0  ...       225.0         859
# ...                                     ...  ...         ...         ...
#  资产减值准备(万元)                          9060.0  ...         0.0         -39
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)           1580.0  ...         0.0        1656
#  无形资产摊销(万元)                           165.0  ...         0.0         254
#  长期待摊费用摊销(万元)                          49.0  ...         0.0           8
#  待摊费用的减少(万元)                            0.0  ...         0.0           0
#  预提费用的增加(万元)                            0.0  ...         0.0           0
#  处置固定资产、无形资产和其他长期资产的损失(万元)            564.0  ...         0.0          27
#  固定资产报废损失(万元)                           0.0  ...         0.0           0
#  公允价值变动损失(万元)                           0.0  ...         0.0           0
#  递延收益增加(减：减少)(万元)                       0.0  ...         0.0           0
#  预计负债(万元)                               0.0  ...         0.0           0
#  财务费用(万元)                               0.0  ...         0.0         159
#  投资损失(万元)                               0.0  ...         0.0       -1203
#  递延所得税资产减少(万元)                      -1828.0  ...         0.0         590
#  递延所得税负债增加(万元)                          0.0  ...         0.0           0
#  存货的减少(万元)                          -5706.0  ...         0.0       -8710
#  经营性应收项目的减少(万元)                     -1604.0  ...         0.0       -2516
#  经营性应付项目的增加(万元)                     -3014.0  ...         0.0       48876
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0  ...         0.0           0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0  ...         0.0           0
#  其他(万元)                                 0.0  ...         0.0           0
#  经营活动产生现金流量净额(万元)                   10708.0  ...         0.0       59492
#  债务转为资本(万元)                             0.0  ...         0.0           0
#  一年内到期的可转换公司债券(万元)                      0.0  ...         0.0           0
#  融资租入固定资产(万元)                           0.0  ...         0.0           0
#  现金的期末余额(万元)                        57405.0  ...     79452.0       72239
#  现金的期初余额(万元)                        50429.0  ...     72239.0       47767
#  现金等价物的期末余额(万元)                         0.0  ...         0.0           0
#  现金等价物的期初余额(万元)                         0.0  ...         0.0           0
#  现金及现金等价物的净增加额(万元)                   6977.0  ...      7213.0       24472
#
#                                  2007-09-30  2007-06-30  2007-03-31  \
#  报告日期
#  销售商品、提供劳务收到的现金(万元)                 94602.0     61992.0     35645.0
#  客户存款和同业存放款项净增加额(万元)                    0.0         0.0         0.0
#  向中央银行借款净增加额(万元                         0.0         0.0         0.0
#  向其他金融机构拆入资金净增加额(万元)                    0.0         0.0         0.0
#  收到原保险合同保费取得的现金(万元)                     0.0         0.0         0.0
#  收到再保险业务现金净额(万元)                        0.0         0.0         0.0
#  保户储金及投资款净增加额(万元)                       0.0         0.0         0.0
#  处置交易性金融资产净增加额(万元)                      0.0         0.0         0.0
#  收取利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  拆入资金净增加额(万元)                           0.0         0.0         0.0
#  回购业务资金净增加额(万元)                         0.0         0.0         0.0
#  收到的税费返还(万元)                           13.0        13.0         0.0
#  收到的其他与经营活动有关的现金(万元)                 5181.0       208.0      6133.0
#  经营活动现金流入小计(万元)                     99796.0     62214.0     41778.0
#  购买商品、接受劳务支付的现金(万元)                 22036.0     12491.0      8285.0
#  客户贷款及垫款净增加额(万元)                        0.0         0.0         0.0
#  存放中央银行和同业款项净增加额(万元)                    0.0         0.0         0.0
#  支付原保险合同赔付款项的现金(万元)                     0.0         0.0         0.0
#  支付利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  支付保单红利的现金(万元)                          0.0         0.0         0.0
#  支付给职工以及为职工支付的现金(万元)                 4756.0      3183.0      1883.0
#  支付的各项税费(万元)                        29786.0     22494.0     10199.0
#  支付的其他与经营活动有关的现金(万元)                15472.0      7600.0      4052.0
#  经营活动现金流出小计(万元)                     72051.0     45769.0     24419.0
#  经营活动产生的现金流量净额(万元)                  27745.0     16446.0     17358.0
#  收回投资所收到的现金(万元)                      3875.0      3845.0         0.0
#  取得投资收益所收到的现金(万元)                       0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)        12.0         0.0      1170.0
#  处置子公司及其他营业单位收到的现金净额(万元)              966.0       991.0       488.0
#  收到的其他与投资活动有关的现金(万元)                  583.0       414.0      3704.0
# ...                                     ...         ...         ...
#  资产减值准备(万元)                             0.0       -77.0         0.0
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)              0.0       825.0         0.0
#  无形资产摊销(万元)                             0.0       122.0         0.0
#  长期待摊费用摊销(万元)                           0.0         0.0         0.0
#  待摊费用的减少(万元)                            0.0         0.0         0.0
#  预提费用的增加(万元)                            0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产的损失(万元)              0.0         0.0         0.0
#  固定资产报废损失(万元)                           0.0         0.0         0.0
#  公允价值变动损失(万元)                           0.0         0.0         0.0
#  递延收益增加(减：减少)(万元)                       0.0         0.0         0.0
#  预计负债(万元)                               0.0         0.0         0.0
#  财务费用(万元)                               0.0       114.0         0.0
#  投资损失(万元)                               0.0     -1172.0         0.0
#  递延所得税资产减少(万元)                          0.0       513.0         0.0
#  递延所得税负债增加(万元)                          0.0         0.0         0.0
#  存货的减少(万元)                              0.0      -297.0         0.0
#  经营性应收项目的减少(万元)                         0.0    -10051.0         0.0
#  经营性应付项目的增加(万元)                         0.0     19576.0         0.0
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0         0.0         0.0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0         0.0         0.0
#  其他(万元)                                 0.0         0.0         0.0
#  经营活动产生现金流量净额(万元)                       0.0     16446.0         0.0
#  债务转为资本(万元)                             0.0         0.0         0.0
#  一年内到期的可转换公司债券(万元)                      0.0         0.0         0.0
#  融资租入固定资产(万元)                           0.0         0.0         0.0
#  现金的期末余额(万元)                        40267.0     29665.0     65267.0
#  现金的期初余额(万元)                        47767.0     47767.0     47767.0
#  现金等价物的期末余额(万元)                         0.0         0.0         0.0
#  现金等价物的期初余额(万元)                         0.0         0.0         0.0
#  现金及现金等价物的净增加额(万元)                  -7499.0    -18102.0     17500.0
#
#                                  2006-12-31  2006-09-30  2006-06-30  \
#  报告日期
#  销售商品、提供劳务收到的现金(万元)                 87939.0     58477.0     32652.0
#  客户存款和同业存放款项净增加额(万元)                    0.0         0.0         0.0
#  向中央银行借款净增加额(万元                         0.0         0.0         0.0
#  向其他金融机构拆入资金净增加额(万元)                    0.0         0.0         0.0
#  收到原保险合同保费取得的现金(万元)                     0.0         0.0         0.0
#  收到再保险业务现金净额(万元)                        0.0         0.0         0.0
#  保户储金及投资款净增加额(万元)                       0.0         0.0         0.0
#  处置交易性金融资产净增加额(万元)                      0.0         0.0         0.0
#  收取利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  拆入资金净增加额(万元)                           0.0         0.0         0.0
#  回购业务资金净增加额(万元)                         0.0         0.0         0.0
#  收到的税费返还(万元)                            0.0         0.0         0.0
#  收到的其他与经营活动有关的现金(万元)                 9439.0      4199.0      3780.0
#  经营活动现金流入小计(万元)                     97377.0     62676.0     36432.0
#  购买商品、接受劳务支付的现金(万元)                 34442.0     16541.0     11319.0
#  客户贷款及垫款净增加额(万元)                        0.0         0.0         0.0
#  存放中央银行和同业款项净增加额(万元)                    0.0         0.0         0.0
#  支付原保险合同赔付款项的现金(万元)                     0.0         0.0         0.0
#  支付利息、手续费及佣金的现金(万元)                     0.0         0.0         0.0
#  支付保单红利的现金(万元)                          0.0         0.0         0.0
#  支付给职工以及为职工支付的现金(万元)                 4970.0      3915.0      2783.0
#  支付的各项税费(万元)                        34921.0     22569.0     17590.0
#  支付的其他与经营活动有关的现金(万元)                 9341.0     20514.0     12148.0
#  经营活动现金流出小计(万元)                     83675.0     63539.0     43840.0
#  经营活动产生的现金流量净额(万元)                  13703.0      -864.0     -7408.0
#  收回投资所收到的现金(万元)                     10819.0     21910.0     17233.0
#  取得投资收益所收到的现金(万元)                      55.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)         1.0         1.0         0.0
#  处置子公司及其他营业单位收到的现金净额(万元)                0.0         0.0         0.0
#  收到的其他与投资活动有关的现金(万元)                  562.0       639.0       587.0
# ...                                     ...         ...         ...
#  资产减值准备(万元)                           283.0         0.0      -153.0
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)           1572.0         0.0       818.0
#  无形资产摊销(万元)                           231.0         0.0       114.0
#  长期待摊费用摊销(万元)                          48.0         0.0        24.0
#  待摊费用的减少(万元)                            0.0         0.0         0.0
#  预提费用的增加(万元)                            0.0         0.0         0.0
#  处置固定资产、无形资产和其他长期资产的损失(万元)              4.0         0.0         0.0
#  固定资产报废损失(万元)                           0.0         0.0         0.0
#  公允价值变动损失(万元)                           0.0         0.0         0.0
#  递延收益增加(减：减少)(万元)                       0.0         0.0         0.0
#  预计负债(万元)                               0.0         0.0         0.0
#  财务费用(万元)                            2117.0         0.0       811.0
#  投资损失(万元)                            -774.0         0.0       -81.0
#  递延所得税资产减少(万元)                         61.0         0.0       -94.0
#  递延所得税负债增加(万元)                          0.0         0.0         0.0
#  存货的减少(万元)                           1700.0         0.0    -25023.0
#  经营性应收项目的减少(万元)                    -16250.0         0.0      5330.0
#  经营性应付项目的增加(万元)                     14261.0         0.0      7249.0
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0         0.0         0.0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0         0.0         0.0
#  其他(万元)                                 0.0         0.0         0.0
#  经营活动产生现金流量净额(万元)                   13703.0         0.0     -7408.0
#  债务转为资本(万元)                             0.0         0.0         0.0
#  一年内到期的可转换公司债券(万元)                      0.0         0.0         0.0
#  融资租入固定资产(万元)                           0.0         0.0         0.0
#  现金的期末余额(万元)                        47767.0     31060.0     24269.0
#  现金的期初余额(万元)                        37811.0     37811.0     37811.0
#  现金等价物的期末余额(万元)                         0.0         0.0         0.0
#  现金等价物的期初余额(万元)                         0.0         0.0         0.0
#  现金及现金等价物的净增加额(万元)                   9955.0     -6752.0    -13542.0
#
#                                  2006-03-31
#  报告日期
#  销售商品、提供劳务收到的现金(万元)                 18163.0
#  客户存款和同业存放款项净增加额(万元)                    0.0
#  向中央银行借款净增加额(万元                         0.0
#  向其他金融机构拆入资金净增加额(万元)                    0.0
#  收到原保险合同保费取得的现金(万元)                     0.0
#  收到再保险业务现金净额(万元)                        0.0
#  保户储金及投资款净增加额(万元)                       0.0
#  处置交易性金融资产净增加额(万元)                      0.0
#  收取利息、手续费及佣金的现金(万元)                     0.0
#  拆入资金净增加额(万元)                           0.0
#  回购业务资金净增加额(万元)                         0.0
#  收到的税费返还(万元)                            0.0
#  收到的其他与经营活动有关的现金(万元)                 1489.0
#  经营活动现金流入小计(万元)                     19652.0
#  购买商品、接受劳务支付的现金(万元)                  5213.0
#  客户贷款及垫款净增加额(万元)                        0.0
#  存放中央银行和同业款项净增加额(万元)                    0.0
#  支付原保险合同赔付款项的现金(万元)                     0.0
#  支付利息、手续费及佣金的现金(万元)                     0.0
#  支付保单红利的现金(万元)                          0.0
#  支付给职工以及为职工支付的现金(万元)                 1799.0
#  支付的各项税费(万元)                        10757.0
#  支付的其他与经营活动有关的现金(万元)                 4755.0
#  经营活动现金流出小计(万元)                     22524.0
#  经营活动产生的现金流量净额(万元)                  -2872.0
#  收回投资所收到的现金(万元)                         0.0
#  取得投资收益所收到的现金(万元)                       0.0
#  处置固定资产、无形资产和其他长期资产所收回的现金净额(万元)         0.0
#  处置子公司及其他营业单位收到的现金净额(万元)                0.0
#  收到的其他与投资活动有关的现金(万元)                 2713.0
# ...                                     ... ..
#  资产减值准备(万元)                             0.0
#  固定资产折旧、油气资产折耗、生产性物资折旧(万元)              0.0
#  无形资产摊销(万元)                             0.0
#  长期待摊费用摊销(万元)                           0.0
#  待摊费用的减少(万元)                            0.0
#  预提费用的增加(万元)                            0.0
#  处置固定资产、无形资产和其他长期资产的损失(万元)              0.0
#  固定资产报废损失(万元)                           0.0
#  公允价值变动损失(万元)                           0.0
#  递延收益增加(减：减少)(万元)                       0.0
#  预计负债(万元)                               0.0
#  财务费用(万元)                               0.0
#  投资损失(万元)                               0.0
#  递延所得税资产减少(万元)                          0.0
#  递延所得税负债增加(万元)                          0.0
#  存货的减少(万元)                              0.0
#  经营性应收项目的减少(万元)                         0.0
#  经营性应付项目的增加(万元)                         0.0
#  已完工尚未结算款的减少(减:增加)(万元)                  0.0
#  已结算尚未完工款的增加(减:减少)(万元)                  0.0
#  其他(万元)                                 0.0
#  经营活动产生现金流量净额(万元)                       0.0
#  债务转为资本(万元)                             0.0
#  一年内到期的可转换公司债券(万元)                      0.0
#  融资租入固定资产(万元)                           0.0
#  现金的期末余额(万元)                        29066.0
#  现金的期初余额(万元)                        37811.0
#  现金等价物的期末余额(万元)                         0.0
#  现金等价物的期初余额(万元)                         0.0
#  现金及现金等价物的净增加额(万元)                  -8745.0
#
# [89 rows x 56 columns]

# %%
cash_columns = df3.iloc[:,0]

# %%
balance_sheet_columns = indexes[0]

# %%
profit_statement_columns = indexes[0]

# %%
columns = pd.DataFrame().from_dict({'cash_flow_columns':cash_columns,
          'balance_sheet_columns':balance_sheet_columns,
          'profit_statement_columns':profit_statement_columns,
          })

# %%
columns.to_csv('columns.csv')

# %%
columns.to_('columns.csv')

# %%
import pickle

# %%
pickle.dump({'cash_flow_columns':cash_columns,
          'balance_sheet_columns':balance_sheet_columns,
          'profit_statement_columns':profit_statement_columns,
          },
           open('columns.h5','w')
           )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-c60dfe21d4fe> in <module>
#       3           'profit_statement_columns':profit_statement_columns,
#       4           },
# ----> 5            open('columns.h5','w')
#       6            )
#
# TypeError: write() argument must be str, not bytes

# %%
from_dict({'cash_flow_columns':cash_columns,
          'balance_sheet_columns':balance_sheet_columns,
          'profit_statement_columns':profit_statement_columns,
          })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-8a720d740e68> in <module>
# ----> 1 pd.from_dict({'cash_flow_columns':cash_columns,
#       2           'balance_sheet_columns':balance_sheet_columns,
#       3           'profit_statement_columns':profit_statement_columns,
#       4           })
#
# AttributeError: module 'pandas' has no attribute 'from_dict'

# %%
import json

# %%
json.dump({'cash_flow_columns':cash_columns,
          'balance_sheet_columns':balance_sheet_columns,
          'profit_statement_columns':profit_statement_columns,
          },
         open('columns.json','w')
         )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-2162b6b5e387> in <module>
#       3           'profit_statement_columns':profit_statement_columns,
#       4           },
# ----> 5          open('columns.json','w')
#       6          )
#
# D:\Miniconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# D:\Miniconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# D:\Miniconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# D:\Miniconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# D:\Miniconda3\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Series is not JSON serializable

# %%
import tushare as ts
import numpy as np

# %%
for i,ix in enumerate(indexes):
    print(i, len(ix))
# Out:
# 0 31
# 1 31
# 2 31
# 3 31
# 4 31
# 5 31
# 6 31
# 7 31
# 8 31
# 9 31
# 10 31
# 11 31
# 12 31
# 13 31
# 14 31
# 15 31
# 16 31
# 17 31
# 18 31
# 19 31
# 20 31
# 21 31
# 22 31
# 23 31
# 24 31
# 25 31
# 26 31
# 27 31
# 28 31
# 29 31

# %%
import time

# %%
stock_list = list(ts.get_stock_basics().index)
indexes = []
for s in stock_list[:30]:
    df = ts.get_profit_statement(s)
    indexes.append(df.iloc[:,0])
    time.sleep(np.random.rand())
# df = ts.get_report_data(2019, 3)

# %%
df = ts.get_cash_flow('600779')

# %%
# ts.get_balance_sheet('601696')
# ts.get_profit_statement('601696')
df = ts.get_cash_flow('600779')

# %%
df1 = ts.get_cash_flow('300063')
df2 = ts.get_cash_flow('000757')
df3 = ts.get_cash_flow('600086')

# %%
len(df3.iloc[:,0])
# Out:
# 76

# %%
df = df.drop(0, axis=0)
df.index = df.iloc[:, 0]
df = df.drop('报表日期', axis=1).T
df = df.astype(float) / 1000000

df['code'] = code
df['date'] = df.index
df['code_date'] = code + '_' + df.index

df.reset_index(drop=True, inplace=True)

# %%
df1 = df[df.date=='20181231']

# %%
df1.to_dict('records')
# Out:
# [{'一、经营活动产生的现金流量': nan,
#   '销售商品、提供劳务收到的现金': 3165.57715826,
#   '收到的税费返还': 0.0,
#   '收到的其他与经营活动有关的现金': 32.89346456,
#   '经营活动现金流入小计': 3198.4706228200002,
#   '购买商品、接受劳务支付的现金': 907.3135937000001,
#   '支付给职工以及为职工支付的现金': 346.43904685,
#   '支付的各项税费': 783.9362026,
#   '支付的其他与经营活动有关的现金': 729.6891746,
#   '经营活动现金流出小计': 2767.37801775,
#   '经营活动产生的现金流量净额': 431.09260507,
#   '二、投资活动产生的现金流量': nan,
#   '收回投资所收到的现金': 0.0,
#   '取得投资收益所收到的现金': 0.0,
#   '处置固定资产、无形资产和其他长期资产所收回的现金净额': 0.046500410000000006,
#   '处置子公司及其他营业单位收到的现金净额': 0.0,
#   '收到的其他与投资活动有关的现金': 0.0,
#   '投资活动现金流入小计': 0.046500410000000006,
#   '购建固定资产、无形资产和其他长期资产所支付的现金': 131.81537018,
#   '投资所支付的现金': 0.0,
#   '取得子公司及其他营业单位支付的现金净额': 0.0,
#   '支付的其他与投资活动有关的现金': 0.0,
#   '投资活动现金流出小计': 131.81537018,
#   '投资活动产生的现金流量净额': -131.76886977,
#   '三、筹资活动产生的现金流量': nan,
#   '吸收投资收到的现金': 0.0,
#   '其中：子公司吸收少数股东投资收到的现金': 0.0,
#   '取得借款收到的现金': 0.0,
#   '发行债券收到的现金': 0.0,
#   '收到其他与筹资活动有关的现金': 0.0,
#   '筹资活动现金流入小计': 0.0,
#   '偿还债务支付的现金': 0.0,
#   '分配股利、利润或偿付利息所支付的现金': 303.06186611000004,
#   '其中：子公司支付给少数股东的股利、利润': 0.0,
#   '支付其他与筹资活动有关的现金': 0.0,
#   '筹资活动现金流出小计': 303.06186611000004,
#   '筹资活动产生的现金流量净额': -303.06186611000004,
#   '四、汇率变动对现金及现金等价物的影响': 0.0,
#   '五、现金及现金等价物净增加额': -3.73813081,
#   '加:期初现金及现金等价物余额': 1028.93070322,
#   '六、期末现金及现金等价物余额': 1025.19257241,
#   '附注': nan,
#   '净利润': 579.44990096,
#   '少数股东权益': 0.0,
#   '未确认的投资损失': 0.0,
#   '资产减值准备': 0.2409482,
#   '固定资产折旧、油气资产折耗、生产性物资折旧': 40.53317759,
#   '无形资产摊销': 4.98106178,
#   '长期待摊费用摊销': 1.95799709,
#   '待摊费用的减少': 0.0,
#   '预提费用的增加': 0.0,
#   '处置固定资产、无形资产和其他长期资产的损失': 7.016041400000001,
#   '固定资产报废损失': 0.0,
#   '公允价值变动损失': 0.0,
#   '递延收益增加（减：减少）': 0.0,
#   '预计负债': -30.0,
#   '财务费用': 0.16673875,
#   '投资损失': 0.0,
#   '递延所得税资产减少': -0.29698684999999997,
#   '递延所得税负债增加': 8.31126093,
#   '存货的减少': -427.55980651,
#   '经营性应收项目的减少': 76.70169604,
#   '经营性应付项目的增加': 168.91326357,
#   '已完工尚未结算款的减少(减:增加)': 0.0,
#   '已结算尚未完工款的增加(减:减少)': 0.0,
#   '其他': -0.03536756,
#   '经营活动产生现金流量净额': 431.09260507,
#   '债务转为资本': 0.0,
#   '一年内到期的可转换公司债券': 0.0,
#   '融资租入固定资产': 0.0,
#   '现金的期末余额': 1025.19257241,
#   '现金的期初余额': 1028.93070322,
#   '现金等价物的期末余额': 0.0,
#   '现金等价物的期初余额': 0.0,
#   '现金及现金等价物的净增加额': -3.73813081,
#   'code': '600779',
#   'date': '20181231',
#   'code_date': '600779_20181231'}]

# %%
dfb = pd.concat([df.iloc[:, :1],df1.iloc[:, :1],df2.iloc[:, :1],], axis=1)

# %%
np.sum(df1.iloc[:, :1] != df.iloc[:, :1])
# Out:
# 报表日期    0
# dtype: int64

# %%
code = '600779'

df = ts.get_balance_sheet(code)
df = df.drop(0, axis=0)
df.index = df.iloc[:,0]


df = df.drop('报表日期', axis=1).T
df = df.astype(float)/1000000

df['code_date'] = code + '_' + df.index

df.reset_index(drop=True, inplace=True)

df.to_sql('lrb', engine, if_exists='replace')

# %%
df
# Out:
# 报表日期  流动资产         货币资金  交易性金融资产  衍生金融资产   应收票据及应收账款        应收票据        应收账款  \
# 0      NaN  1174.183781      0.0     0.0   18.748983    0.000000   18.748983
# 1      NaN  1504.754533      0.0     0.0   25.341477    0.000000   25.341477
# 2      NaN  1261.794094      0.0     0.0   16.049216    3.918747   12.130469
# 3      NaN  1025.867949      0.0     0.0   34.292224    0.000000   34.292224
# 4      NaN   794.207223      0.0     0.0   34.446488    4.370267   30.076221
# 5      NaN   948.146350      0.0     0.0   45.828073   10.131252   35.696821
# 6      NaN   912.520499      0.0     0.0  102.850519    6.586500   96.264019
# 7      NaN  1029.570712      0.0     0.0   87.679760    5.868270   81.811490
# 8      NaN   836.648189      0.0     0.0    0.000000    7.565412   35.207378
# 9      NaN   794.694581      0.0     0.0   11.538489    0.000000   11.538489
# 10     NaN   864.054120      0.0     0.0    0.000000    5.000000    7.048834
# 11     NaN   724.885788      0.0     0.0   17.291495    0.000000   17.291495
# 12     NaN   622.048370      0.0     0.0    0.000000    0.000000    2.697826
# 13     NaN   445.312583      0.0     0.0    2.422172    1.530000    0.892172
# 11  ...    381.909848     0.0            0.0       0.0   504.285967
# 12  ...      0.000000     0.0            0.0       0.0     0.000000
# 13  ...     87.909568     0.0            0.0       0.0   444.712763
# 14  ...      0.000000     0.0            0.0       0.0     0.000000
# 15  ...    234.037093     0.0            0.0       0.0   363.650160
# 16  ...      0.000000     0.0            0.0       0.0     0.000000
# 17  ...     35.573806     0.0            0.0       0.0   129.703892
# 18  ...      0.000000     0.0            0.0       0.0     0.000000
# 19  ...   -105.887184     0.0            0.0       0.0    98.995909
# 20  ...      0.000000     0.0            0.0       0.0     0.000000
# 21  ...    -94.953544     0.0            0.0       0.0   110.921802
# 22  ...      0.000000     0.0            0.0       0.0     0.000000
# 23  ...   -440.726118     0.0            0.0       0.0   239.512631
# 24  ...      0.000000     0.0            0.0       0.0     0.000000
# 25  ...   -271.886747     0.0            0.0       0.0   421.892742
# 26  ...      0.000000     0.0            0.0       0.0     0.000000
# 27  ...     62.583789     0.0            0.0       0.0   232.876771
# 28  ...      0.000000     0.0            0.0       0.0     0.000000
# 29  ...     53.946913     0.0            0.0       0.0   457.125348
# ..  ...           ...     ...            ...       ...          ...
# 48  ...      0.000000     0.0            0.0       0.0   402.671341
# 49  ...    164.455528     0.0            0.0       0.0   296.645343
# 50  ...      0.000000     0.0            0.0       0.0   652.667559
# 51  ...    137.027689     0.0            0.0       0.0   477.665089
# 52  ...     -8.635515     0.0            0.0       0.0   310.595552
# 53  ...    -74.079757     0.0            0.0       0.0   242.690756
# 54  ...    -28.723040     0.0            0.0       0.0   290.661495
# 55  ...     86.984271     0.0            0.0       0.0   378.111382
# 56  ...    -51.187428     0.0            0.0       0.0   305.130534
# 57  ...    -71.366837     0.0            0.0       0.0   265.148312
# 58  ...     17.128651     0.0            0.0       0.0   433.262024
# 59  ...    149.570827     0.0            0.0       0.0   349.450345
# 60  ...    -73.521270     0.0            0.0       0.0   245.489691
# 61  ...    -50.683449     0.0            0.0       0.0   255.345180
# 62  ...     13.033586     0.0            0.0       0.0   288.987238
# 63  ...    170.429381     0.0            0.0       0.0   347.509744
# 64  ...     48.072288     0.0            0.0       0.0   254.291524
# 65  ...    132.933491     0.0            0.0       0.0   312.961006
# 66  ...     42.293067     0.0            0.0       0.0   272.284498
# 67  ...    131.026508     0.0            0.0       0.0   325.841815
# 68  ...     -9.480503     0.0            0.0       0.0   358.348754
# 69  ...    113.873005     0.0            0.0       0.0   428.199026
# 70  ...     84.025246     0.0            0.0       0.0   252.186441
# 71  ...    139.930476     0.0            0.0       0.0   240.289013
# 72  ...     91.898120     0.0            0.0       0.0   224.155612
# 73  ...    151.211791     0.0            0.0       0.0   155.945440
# 74  ...    -36.408387     0.0            0.0       0.0   174.111106
# 75  ...     45.265782     0.0            0.0       0.0   130.797681
# 76  ...    -15.376660     0.0            0.0       0.0   128.309819
# 77  ...      0.000000     0.0            0.0       0.0     0.000000
#
#         现金的期初余额  现金等价物的期末余额  现金等价物的期初余额  现金及现金等价物的净增加额    code
# 0      0.000000         0.0         0.0       0.000000  600779
# 1   1025.192572         0.0         0.0     478.831447  600779
